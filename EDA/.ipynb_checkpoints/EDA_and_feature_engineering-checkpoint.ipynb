# %%
library(dplyr)
library(readr)

#Load dataset
raw_geolocation = read_csv("../CleanedDataset/corrected_geolocation.csv")
raw_order = read_csv("../CleanedDataset/order.csv")
raw_product_measure = read_csv("../CleanedDataset/product_measure.csv")
raw_seller = read_csv("../CleanedDataset/seller.csv")

order = raw_order %>%
  select(order_id, product_id, order_products_value, order_freight_value, product_category_name, 
         customer_city, customer_state, customer_zip_code_prefix,
         order_purchase_timestamp, order_aproved_at, order_delivered_customer_date)
# Out:
# Attaching package: 'dplyr'
#
# The following objects are masked from 'package:stats':
#
#     filter, lag
#
# The following objects are masked from 'package:base':
#
#     intersect, setdiff, setequal, union
#
# Parsed with column specification:
# cols(
#   zip_code_prefix = col_integer(),
#   city = col_character(),
#   state = col_character(),
#   lat = col_double(),
#   lng = col_double()
# )
# Parsed with column specification:
# cols(
#   .default = col_character(),
#   order_products_value = col_double(),
#   order_freight_value = col_double(),
#   order_items_qty = col_integer(),
#   order_sellers_qty = col_integer(),
#   order_purchase_timestamp = col_datetime(format = ""),
#   order_aproved_at = col_datetime(format = ""),
#   order_estimated_delivery_date = col_datetime(format = ""),
#   order_delivered_customer_date = col_datetime(format = ""),
#   product_name_lenght = col_integer(),
#   product_description_lenght = col_integer(),
#   product_photos_qty = col_integer(),
#   review_score = col_integer(),
#   review_creation_date = col_datetime(format = ""),
#   review_answer_timestamp = col_datetime(format = "")
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   product_id = col_character(),
#   product_weight_g = col_double(),
#   product_length_cm = col_double(),
#   product_height_cm = col_double(),
#   product_width_cm = col_double()
# )
# Parsed with column specification:
# cols(
#   order_id = col_character(),
#   product_id = col_character(),
#   seller_id = col_character(),
#   seller_zip_code_prefix = col_character(),
#   seller_city = col_character(),
#   seller_state = col_character()
# )

# %% [markdown]
# ## Feature Engineering:
# 1. Compute delivery time at order dataset
# 2. Add product information to the order dataset
# 3. Compute the distance between the seller and the customer, based on (zip_code, city)
# 4. Add cluster label for each (customer_city, customer_state)

# %%
#Compute delivery time
order = order %>%
  mutate(delivery_time = as.numeric(order_delivered_customer_date - order_purchase_timestamp, units="days"),
         order_purchase_timestamp = NULL,
         order_aproved_at = NULL,
         order_delivered_customer_date = NULL) %>%
  filter(! is.na(delivery_time))

# %%
#Add product_size & weights
product = raw_product_measure %>%
  mutate(size = product_length_cm * product_height_cm * product_width_cm,
         weight = product_weight_g) %>%
  select(product_id, size, weight)

order = order %>% 
  left_join(product, by="product_id") %>%
  filter(! is.na(size)) %>%
  mutate(product_category_name = NULL)

# %%
#------------------------------------------------------------------------------------------------------
#Compute distance between seller and customer based on (zip_code, city)
#------------------------------------------------------------------------------------------------------
#Compute the geographical center of each (zip_code, city)
geolocation = raw_geolocation %>%
  group_by(zip_code_prefix, city) %>%
  summarize(lat = mean(lat),
            lng = mean(lng))

#Incorporate the location information
order = order %>%
  mutate(customer_city = tolower(customer_city),
         customer_zip_code_prefix = as.integer(customer_zip_code_prefix)) %>%
  left_join(geolocation %>%
              ungroup() %>%
              mutate(customer_city = tolower(city),
                     customer_zip_code_prefix = zip_code_prefix,
                     customer_lat = lat,
                     customer_lng = lng) %>%
              select(starts_with("customer")), by=c("customer_zip_code_prefix", "customer_city")) %>%
  filter(!is.na(customer_lat))

order = order %>%
  left_join(raw_seller, by=c("order_id", "product_id")) %>%
  mutate(seller_city = tolower(seller_city),
         seller_zip_code_prefix = as.integer(seller_zip_code_prefix)) %>%
  left_join(geolocation %>%
              ungroup() %>%
              mutate(seller_city = tolower(city),
                     seller_zip_code_prefix = zip_code_prefix,
                     seller_lat = lat,
                     seller_lng = lng) %>%
              select(starts_with("seller")), by=c("seller_zip_code_prefix", "seller_city")) %>%
  filter(!is.na(seller_lat))

#Convert location to distance on Earth; Using Spherical Law of Cosines to compute distance
distance <- function(lat1, lng1, lat2, lng2){
  R = 6371 #Radius of Earth in km
  dang = sin(lat1) * sin(lat2) + cos(lat1) * cos(lat2) * cos(lng2 - lng1)
  return(R * acos(pmax(pmin(dang, 1), -1)))
}
ang2rad <- function(ang){
  return(ang * pi / 180)
}
order = order %>% 
  mutate(distance = distance(ang2rad(customer_lat), ang2rad(customer_lng),
                             ang2rad(seller_lat), ang2rad(seller_lng)),
         customer_lat = NULL,
         customer_lng = NULL,
         seller_lat = NULL,
         seller_lng = NULL)

# %%
#Add cluster label for each (customer_city, customer_state)
cluster = order %>% 
  group_by(customer_city, customer_state) %>%
  summarize(cluster = n())

cluster$cluster = seq(1, nrow(cluster))

order = order %>%
  left_join(cluster, by=c("customer_city", "customer_state"))

head(order)
# Out:
#   order_id                         product_id
# 1 b95df3cef5297e79ef709ba256518f6f 6cdd53843498f92890544667809f1595
# 2 59af46052a799e80e2f0c665c587731d ae5cad88462eb7b7b61401e31c45618e
# 3 a3e6136894621db402a772c6bc72a12a 0c9ff9d8ed9b9bdd825487b3a66e05f5
# 4 b675ea5a618922f6e679e30531b8957b ad0a798e7941f3a5a2fb8139cb62ad78
# 5 195a8be6794c487fe6cfbb97b7c61902 eaf2046d4c87809247a30050ea13df03
# 6 80dbbd6f2282898dbf912a2ec668175f 167752e318335bf6bdd6906c4c470266
#   order_products_value order_freight_value customer_city customer_state
# 1 349.90               13.84               guaratuba     PR
# 2  15.00               15.10               uberlandia    MG
# 3 238.90               18.00               itapevi       SP
# 4  29.99               18.23               goiania       GO
# 5 295.99               47.65               recife        PE
# 6 160.00               19.00               rio grande    RS
#   customer_zip_code_prefix delivery_time size  weight
# 1 832                       5.739851     11400  900
# 2 384                       4.017214     19200  250
# 3  66                       6.946479     48373 7950
# 4 743                      23.095923      2560  550
# 5 511                      14.449048     13851 3800
# 6 962                      15.414710      2016  200
#   seller_id                        seller_zip_code_prefix seller_city
# 1 ccc4bbb5f32a6ab2b7066a4130f114e3 803                    curitiba
# 2 ce27a3cc3c8cc1ea79d11e561e9bebb6  30                    sao paulo
# 3 8581055ce74af1daba164fdbd55a40de  71                    guarulhos
# 4 1835b56ce799e6a4dc4eddc053f04066 149                    ibitinga
# 5 8bd0f31cf0a614c658f6763bd02dea69  12                    sao paulo
# 6 7e1fb0a3ebfb01ffb3a7dae98bf3238d 144                    franca
#   seller_state distance   cluster
# 1 PR             86.17268 1491
# 2 SP            542.41402 3871
# 3 SP             48.62742 1764
# 4 SP            562.43999 1410
# 5 SP           2123.85026 2972
# 6 SP           1366.05927 3056

# %% [markdown]
# ## EDA
# I first visualize the distribution of the delivery time for each order:

# %%
summary(order$delivery_time)
hist(order$delivery_time, breaks=100)
# Out:
#     Min.  1st Qu.   Median     Mean  3rd Qu.     Max.
#   0.5334   6.9726  10.4990  12.7322  15.8519 209.6286
# Plot with title "Histogram of order$delivery_time"

# %% [markdown]
# From the above figure, we can see that there are some outliers for the delivery time, and the delivery time follows approximately some Gamma distribution.
#
# I then visualize the distribution of the distance for each order:

# %%
summary(order$distance)
hist(order$distance, breaks=100)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#     0.0   207.4   437.5   597.7   788.3  3437.7
# Plot with title "Histogram of order$distance"

# %% [markdown]
# Then, I try to visualize the delivery time over different cities, jointly with the GDP figure of each city. This visualization aims to help me understand how the location affects the delivery time, as well as whether prosperity factor (as reflected by the GDP level) is also a contributing factor.

# %%
raw_GDP_city = read_csv("../CleanedDataset/GDP_by_city_2010.csv")

#Preprocess the GDP_city table:
#Compute the geographical center of each (state, city)
geolocation = raw_geolocation %>%
  group_by(city, state) %>%
  summarize(lat = mean(lat),
            lng = mean(lng))

GDP_city = raw_GDP_city %>%
  mutate(city = tolower(city_by_data),
         state = tolower(state)) %>%
  filter(! is.na(city_by_data)) %>%
  select(city, state, GDP) %>%
  arrange(-GDP)

#Ordered by GDP level
GDP_city$rank = seq(1, nrow(GDP_city))

#Join the two table
GDP_city = GDP_city %>%
  left_join(geolocation, by=c("state", "city"))
# Out:
# Parsed with column specification:
# cols(
#   municipalities = col_character(),
#   GDP = col_double(),
#   city_by_data = col_character(),
#   state = col_character()
# )

# %% [markdown]
# 1. Delivery time distribution over the seller cities

# %%
library(plot3D)
colvar = order %>%
  mutate(city = tolower(seller_city),
         state = tolower(seller_state)) %>%
  group_by(city, state) %>%
  summarize(mean_delivery = mean(delivery_time)) %>%
  arrange(-mean_delivery) %>%
  left_join(geolocation, by=c("city", "state"))

summary(colvar$mean_delivery)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#   3.066  10.799  12.798  13.476  14.998  95.183

# %%
#remove the outlier, and to make a stronger color constrast over different region
colvar = colvar %>%
  filter(mean_delivery < 60)

scatter2D(colvar$lng, colvar$lat, colvar=colvar$mean_delivery,
          pch = 19, cex = 0.5, main = "Geographical distribution and wealthy cities, on seller level",
          xlab = "lng", ylab = "lat")
# Out:
# Plot with title ""

# %% [markdown]
# I then constrast with the GDP level over cities. Since the collected GDP data of cities is quite outdated (in 2010), it would be more appropriate to use the GDP rank for visualization.

# %%
scatter2D(colvar$lng, colvar$lat, colvar=colvar$mean_delivery,
          pch = 19, cex = 0.5, main = "Geographical distribution and wealthy cities, on seller level",
          xlab = "lng", ylab = "lat")
points(GDP_city$lng, GDP_city$lat, col='orange', pch = 18, cex = 40/(25+GDP_city$rank))
# Out:
# Plot with title ""

# %% [markdown]
# It seems to me that, the seller location is not much related to the delivery time estimation. I then try to visualize the delivery time distribution over the customer cities.

# %% [markdown]
# 2. Delivery time distribution over the customer cities

# %%
colvar = order %>%
  mutate(city = tolower(customer_city),
         state = tolower(customer_state)) %>%
  group_by(city, state) %>%
  summarize(mean_delivery = mean(delivery_time)) %>%
  arrange(-mean_delivery) %>%
  left_join(geolocation, by=c("city", "state"))

summary(colvar$mean_delivery)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#   2.031  11.262  14.543  16.131  18.935 130.681

# %%
#remove the outlier, and to make a stronger color constrast over different region
colvar = colvar %>%
  filter(mean_delivery < 90)

scatter2D(colvar$lng, colvar$lat, colvar=colvar$mean_delivery,
          pch = 19, cex = 0.5, main = "Geographical distribution and wealthy cities, on customer level",
          xlab = "lng", ylab = "lat")
# Out:
# Plot with title ""

# %%
#Constrast with the GDP level over cities
scatter2D(colvar$lng, colvar$lat, colvar=colvar$mean_delivery,
          pch = 19, cex = 0.5, main = "Geographical distribution and wealthy cities, on customer level",
          xlab = "lng", ylab = "lat")
points(GDP_city$lng, GDP_city$lat, col='orange', pch = 18, cex = 40/(25+GDP_city$rank))
# Out:
# Plot with title ""

# %% [markdown]
# From the above figure, it seems to me that the customer cities are more related to the delivery time estimation, as the delivery time is generally larger for the cities in the top left region. Also, most of the wealthy cities are located at the bottom right region, and the delivery time for that region is generally smaller. The prosperity effect of cities really affect the delivery time. Also observed from the graph, the latitude of the city affects the delivery time as well.

# %%
#The relation between latitude of city and the mean delivery time.
cor(colvar$mean_delivery, colvar$lat)
# Out:
# [1] 0.4237511

# %% [markdown]
# 3. Delivery time distribution over the local region around the 3 major cities

# %%
center = geolocation %>%
  filter(city == "brasilia" & state == "df" |
           city == "sao paulo" & state == "sp" |
           city == "rio de janeiro" & state == "rj")

local = order %>%
  mutate(city = tolower(customer_city),
         state = tolower(customer_state)) %>%
  group_by(city, state) %>%
  summarize(mean_delivery = mean(delivery_time)) %>%
  arrange(-mean_delivery) %>%
  left_join(geolocation, by=c("city", "state")) %>%
  filter(lat <= -12, lat >= -28,
         lng <= -40, lng >= -52)

scatter2D(local$lng, local$lat, colvar = local$mean_delivery,
          pch = 19, cex = 0.5, main="Neighbourhood of three wealthy cities",
          xlab = "lng", ylab = "lat")
points(center$lng, center$lat, col='orange', pch = 18, cex = 2)
# Out:
# Plot with title ""

# %% [markdown]
# Lastly, I visualize the distribution of the delivery time around the 3 most wealthy cities to see if the distance between that city and the most wealthy cities (as another measure of prosperity effect) affects the delivery time as well. However, it seems to me it is not much related.

# %% [markdown]
# After EDA and feature engineering, I prepare the dataset for later statistical modelling for deeper analysis.

# %%
# Prepare the dataset for statistical modelling
dataset = order %>%
  select(size, order_products_value, order_freight_value, distance, cluster, customer_state, customer_city, delivery_time)

write_csv(dataset, "../StatisticalAnalysis/dataset.csv")

head(dataset)
# Out:
#   size  order_products_value order_freight_value distance   cluster
# 1 11400 349.90               13.84                 86.17268 1491
# 2 19200  15.00               15.10                542.41402 3871
# 3 48373 238.90               18.00                 48.62742 1764
# 4  2560  29.99               18.23                562.43999 1410
# 5 13851 295.99               47.65               2123.85026 2972
# 6  2016 160.00               19.00               1366.05927 3056
#   customer_state customer_city delivery_time
# 1 PR             guaratuba      5.739851
# 2 MG             uberlandia     4.017214
# 3 SP             itapevi        6.946479
# 4 GO             goiania       23.095923
# 5 PE             recife        14.449048
# 6 RS             rio grande    15.414710
